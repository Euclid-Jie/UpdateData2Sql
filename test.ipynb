# %% [markdown]
# # AKshare获取指数数据

# %%
import akshare as ak

stock_zh_a_daily_qfq_df = ak.stock_zh_a_daily(
    symbol="sh000016", start_date="20250101", end_date="20250801"
)
data = stock_zh_a_daily_qfq_df[
    ["date", "open", "high", "low", "close", "volume", "amount"]
].rename(
    columns={
        "open": "OPEN",
        "high": "HIGH",
        "low": "LOW",
        "close": "CLOSE",
        "volume": "VLOUME",
        "amount": "AMT",
    }
)
data["PCT_CHG"] = data["CLOSE"].pct_change() * 100

# %% [markdown]
# # wind指数网站获取指数数据

# %%
import requests
import pandas as pd

# https://www.windindices.com/indices/zh/IndexF9/e2d5a98547c3ee7c923a0259cee963e4
url = "https://indexapi.wind.com.cn/indicesWebsite/api/Kline?indexId=6644c422b6edae80b3c7a7d55803bc9e&period=1Y&lan=cn"
res = requests.get(url)
data = pd.DataFrame(res.json()["Result"]["data"])
data = data[["tradeDate", "open", "hight", "low", "close", "pctChange", "volume", "amount"]]

# %%
data.rename(
    columns={
        "tradeDate": "date",
        "open": "OPEN",
        "hight": "HIGH",
        "low": "LOW",
        "close": "CLOSE",
        "pctChange": "PCT_CHG",
        "volume": "VOLUME",
        "amount": "AMT",
    }
)
# Out:
#          date         OPEN         HIGH          LOW        CLOSE   PCT_CHG  \
# 0    20240802  221794.4531  223606.9219  219783.7344  219973.1719 -1.328707
# 1    20240805  218919.7813  222168.5781  215101.4688  215103.7969 -2.213622
# 2    20240806  217058.5469  221364.8750  217058.5469  221364.8750  2.910724
# 3    20240807  221867.2813  222546.5781  220096.0469  221525.6094  0.072611
# 4    20240808  221106.7344  222534.5156  217900.0156  221980.3594  0.205281
# ..        ...          ...          ...          ...          ...       ...
# 237  20250728  470595.2449  475328.4805  470525.9424  475130.5151  1.055302
# 238  20250729  476736.9756  476900.6297  469715.3937  474585.7004 -0.114666
# 239  20250730  474047.3739  476330.8669  470333.4790  475096.2025  0.107568
# 240  20250731  473452.8027  476778.4380  467270.1280  468807.8897 -1.323587
# 241  20250801  469700.6267  477616.7526  469466.5738  477021.4323  1.752006
#
#            VOLUME           AMT
# 0    2.275304e+09  1.232747e+10
# 1    2.472553e+09  1.318106e+10
# 2    2.174654e+09  1.163576e+10
# 3    2.078274e+09  1.129093e+10
# 4    2.539888e+09  1.315276e+10
# ..            ...           ...
# 237  3.196147e+09  3.797102e+10
# 238  3.461563e+09  4.061039e+10
# 239  3.510553e+09  4.142014e+10
# 240  3.664536e+09  4.188746e+10
# 241  3.366718e+09  4.076956e+10
#
# [242 rows x 8 columns]

# %% [markdown]
# # 中证指数网站获取指数数据

# %%
# https://www.csindex.com.cn/#/indices/family/detail?indexCode=000985
url = "https://www.csindex.com.cn/csindex-home/perf/index-perf?indexCode=000985&startDate=20250101&endDate=20250803"
res = requests.get(url)
data = res.json()["data"]
pd.DataFrame(data)
# Out:
#     tradeDate indexCode indexNameCnAll indexNameCn       indexNameEnAll  \
# 0    20250101    000985         中证全指指数        中证全指  CSI All Share Index
# 1    20250102    000985         中证全指指数        中证全指  CSI All Share Index
# 2    20250103    000985         中证全指指数        中证全指  CSI All Share Index
# 3    20250106    000985         中证全指指数        中证全指  CSI All Share Index
# 4    20250107    000985         中证全指指数        中证全指  CSI All Share Index
# ..        ...       ...            ...         ...                  ...
# 137  20250728    000985         中证全指指数        中证全指  CSI All Share Index
# 138  20250729    000985         中证全指指数        中证全指  CSI All Share Index
# 139  20250730    000985         中证全指指数        中证全指  CSI All Share Index
# 140  20250731    000985         中证全指指数        中证全指  CSI All Share Index
# 141  20250801    000985         中证全指指数        中证全指  CSI All Share Index
#
#        indexNameEn     open     high      low    close  change  changePct  \
# 0    CSI All Share  4744.65  4748.53  4589.84  4625.11 -125.56      -2.64
# 1    CSI All Share  4744.65  4748.53  4589.84  4625.11 -125.56      -2.64
# 2    CSI All Share  4632.29  4642.26  4518.41  4523.12 -101.99      -2.21
# 3    CSI All Share  4516.66  4547.60  4478.73  4509.93  -13.19      -0.29
# 4    CSI All Share  4506.70  4568.65  4496.29  4567.61   57.68       1.28
# ..             ...      ...      ...      ...      ...     ...        ...
# 137  CSI All Share  5223.98  5242.28  5204.29  5238.80   17.85       0.34
# 138  CSI All Share  5233.47  5263.08  5208.24  5262.32   23.52       0.45
# 139  CSI All Share  5254.58  5279.80  5204.95  5241.33  -20.99      -0.40
# 140  CSI All Share  5228.70  5238.28  5152.86  5168.75  -72.58      -1.38
# 141  CSI All Share  5164.90  5187.93  5136.19  5161.09   -7.66      -0.15
#
#      tradingVol  tradingValue  consNumber    peg
# 0     121711.36      13826.20      5062.0  15.85
# 1     121711.36      13826.20      5062.0  15.85
# 2     117546.10      12512.62      5062.0  15.57
# 3      99508.78      10466.75      5062.0  15.55
# 4      97775.70      10649.81      5062.0  15.68
# ..          ...           ...         ...    ...
# 137   124158.71      17255.14      5073.0  16.94
# 138   126385.96      17894.22      5073.0  16.80
# 139   131610.64      18278.93      5073.0  16.78
# 140   135724.33      19161.81      5073.0  16.56
# 141   110330.43      15821.58      5073.0  16.52
#
# [142 rows x 16 columns]
